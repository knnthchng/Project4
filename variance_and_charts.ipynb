# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv('Resources/train.csv')
data
# Out:
#                     Employee ID Date of Joining  Gender Company Type  \
# 0      fffe32003000360033003200      2008-09-30  Female      Service
# 1          fffe3700360033003500      2008-11-30    Male      Service
# 2      fffe31003300320037003900      2008-03-10  Female      Product
# 3      fffe32003400380032003900      2008-11-03    Male      Service
# 4      fffe31003900340031003600      2008-07-24  Female      Service
# ...                         ...             ...     ...          ...
# 22745  fffe31003500370039003100      2008-12-30  Female      Service
# 22746  fffe33003000350031003800      2008-01-19  Female      Product
# 22747          fffe390032003000      2008-11-05    Male      Service
# 22748  fffe33003300320036003900      2008-01-10  Female      Service
# 22749      fffe3400350031003800      2008-01-06    Male      Product
#
#       WFH Setup Available  Designation  Resource Allocation  \
# 0                      No          2.0                  3.0
# ...

# %%
# Rename columns for better comprehensibility
data = data.rename(columns={"Designation": "Rank",
                           "Resource Allocation":"Hours Worked Per Day",
                           "Burn Rate": "Burnout Rate"})

# %%
# Mean of all numerical variables

values_rank = data['Rank']
values_hours = data['Hours Worked Per Day']
values_fatigue = data['Mental Fatigue Score']
values_burnout = data['Burnout Rate']

mean_values = np.mean(values_rank)
mean_hours = np.mean(values_hours)
mean_fatigue = np.mean(values_fatigue)
mean_burnout = np.mean(values_burnout)

print("Rank Average:", mean_values)
print("Average Hours Worked per Day:", mean_hours)
print("Mental Fatigue Score Average:", mean_fatigue)
print("Burnout Rate Average:", mean_burnout)
# Out:
# Rank Average: 2.1787252747252746
# Average Hours Worked per Day: 4.481398287238523
# Mental Fatigue Score Average: 5.728187854407987
# Burnout Rate Average: 0.45200545639508

# %%
# Median of all numerical values
median_rank = values_rank.median()
median_hours = values_hours.median()
median_fatigue = values_fatigue.median()
median_burnout = values_burnout.median()

print("Designation Median:", median_rank)
print("Resource Allocation Median:", median_hours)
print("Mental Fatigue Score Median:", median_fatigue)
print("Burn Rate Median:", median_burnout)
# Out:
# Designation Median: 2.0
# Resource Allocation Median: 4.0
# Mental Fatigue Score Median: 5.9
# Burn Rate Median: 0.45

# %%
# Mode of all variables
mode_value = data.mode().iloc[0]

print("Mode:", mode_value)
# Out:
# Mode: Employee ID               fffe3100
# Date of Joining         2008-01-06
# Gender                      Female
# Company Type               Service
# WFH Setup Available            Yes
# Rank                           2.0
# Hours Worked Per Day           4.0
# Mental Fatigue Score           6.0
# Burnout Rate                  0.47
# Name: 0, dtype: object

# %%
# Standard Deviation of numerical variables

std_rank = np.std(values_rank)
std_hours = np.std(values_hours)
std_fatigue = np.std(values_fatigue)
std_burnout = np.std(values_burnout)

print("Designation Standard Deviation:", std_rank)
print("Resource Allocation Standard Deviation:", std_hours)
print("Mental Fatigue Score Standard Deviation:", std_fatigue)
print("Burn Rate Standard Deviation:", std_burnout)
# Out:
# Designation Standard Deviation: 1.1351197454954034
# Resource Allocation Standard Deviation: 2.047163218610548
# Mental Fatigue Score Standard Deviation: 1.920792139677332
# Burn Rate Standard Deviation: 0.19822178639142551

# %%
# Gender Composition

column_values = data['Gender']

value_counts = column_values.value_counts()

plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Gender')
plt.show()

save_path = 'Visuals/fig_1.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Company Type Disparity

column_values = data['Company Type']

value_counts = column_values.value_counts()

plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Company Type')
plt.show()

save_path = 'Visuals/fig_2.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# WFH Setup Disparity

column_values = data['WFH Setup Available']

value_counts = column_values.value_counts()

plt.figure(figsize=(8, 6))
plt.pie(value_counts, labels=value_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('WFH')
plt.show()

save_path = 'Visuals/fig_3.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Burn Rate compared to Designation
x_values = data['Burn Rate']
y_values = data['Designation']

plt.scatter(x_values, y_values)
plt.xlabel('Burnout Rate')
plt.ylabel('Rank')
plt.title('Burn Rate vs Rank')
plt.show()

save_path = 'Downloads/fig_4.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/pythondata/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/pythondata/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Burn Rate'
#
# ...

# %%
# Burn Rate compared to Designation
x_values = data['Burn Rate']
y_values = data['Resource Allocation']

plt.scatter(x_values, y_values)
plt.xlabel('Burn Rate')
plt.ylabel('Resource Allocation')
plt.title('Burn Rate vs Resource Allocation')
plt.show()

save_path = 'Downloads/fig_5.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')

# %%
# Burn Rate compared to Mental Fatigue Score
x_values = data['Burn Rate']
y_values = data['Mental Fatigue Score']

plt.scatter(x_values, y_values)
plt.xlabel('Burn Rate')
plt.ylabel('Mental Fatigue Score')
plt.title('Burn Rate vs Mental Fatigue Score')
plt.show()

save_path = 'Downloads/fig_6.png'
plt.savefig(save_path, dpi=300, bbox_inches='tight')
